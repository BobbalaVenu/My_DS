# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\User\Desktop\Data Science & AI\Projects\Pandas Project\movie.csv")
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
ratings = pd.read_csv(r"C:\Users\User\Desktop\Data Science & AI\Projects\Pandas Project\Rating.csv")
ratings
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
tags = pd.read_csv(r"C:\Users\User\Desktop\Data Science & AI\Projects\Pandas Project\tag.csv")
tags
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
del ratings['timestamp']

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
del tags ['timestamp']
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465564 rows x 3 columns]

# %%
row_0 = tags.iloc[0]
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.tail()
# Out:
#         userId  movieId            tag
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,500]]
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 11       65     1783      noir thriller
# 500     342    55908  entirely dialogue

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating']>10
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %%
filter2 = ratings['rating']>0
filter2.all()
# Out:
# True

# %%
movies.shape
# Out:
# (27278, 3)

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
tags.shape
# Out:
# (465564, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull()
# Out:
#           userId  movieId  rating
# 0          False    False   False
# 1          False    False   False
# 2          False    False   False
# 3          False    False   False
# 4          False    False   False
# ...          ...      ...     ...
# 20000258   False    False   False
# 20000259   False    False   False
# 20000260   False    False   False
# 20000261   False    False   False
# 20000262   False    False   False
#
# [20000263 rows x 3 columns]

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
tags = tags.dropna()

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
tags.shape
# Out:
# (465548, 3)

# %%
# %matplotlib inline
ratings.hist(column='rating',figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>]], dtype=object)

# %%
ratings.boxplot(column='rating',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tags_count=tags['tag'].value_counts()

# %%
tags_count[-10:]
# Out:
# Carlos Marques-Marcet         1
# related:King Lear             1
# ashamed of source material    1
# what if                       1
# Score                         1
# uncooperative characters      1
# vibrator                      1
# historical lackluster         1
# Pretty Woman twist            1
# Treva Wurmfeld                1
# Name: tag, dtype: int64

# %%
tags_count[:10].plot(kind='bar',figsize=(10,5))

# %%
tags_count[:].plot(kind='bar',figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-fe182df9ddc8> in <module>
# ----> 1 tags_count[:].plot(kind='bar',figsize=(10,5))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     278         self._compute_plot_data()
# ...

# %%
tags_count[:10].plot(kind='bar',figsize=(10,5))

# %%
tags_count[:10].plot(kind='bar',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
Highly_rated = ratings['rating']>=5
Highly_rated
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261     True
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool

# %%
ratings[Highly_rated][30:50]
# Out:
#      userId  movieId  rating
# 239       3       50     5.0
# 242       3      175     5.0
# 244       3      223     5.0
# 245       3      260     5.0
# 246       3      316     5.0
# 247       3      318     5.0
# 248       3      329     5.0
# 252       3      457     5.0
# 253       3      480     5.0
# 254       3      490     5.0
# 256       3      541     5.0
# 258       3      593     5.0
# 263       3      858     5.0
# 264       3      904     5.0
# 267       3      924     5.0
# 268       3      953     5.0
# 271       3     1060     5.0
# 272       3     1073     5.0
# 275       3     1084     5.0
# 276       3     1089     5.0

# %%
is_action=movies['genres'].str.contains('Action')

# %%
movies[is_action][10:20]
# Out:
#      movieId                                       title  \
# 69        70                  From Dusk Till Dawn (1996)
# 70        71                            Fair Game (1995)
# 75        76                            Screamers (1995)
# 77        78                  Crossing Guard, The (1995)
# 85        86                         White Squall (1996)
# 88        89                         Nick of Time (1995)
# 93        95                         Broken Arrow (1996)
# 96        98                             Shopping (1994)
# 108      110                           Braveheart (1995)
# 110      112  Rumble in the Bronx (Hont faan kui) (1995)
#
#                             genres
# 69   Action|Comedy|Horror|Thriller
# 70                          Action
# 75          Action|Sci-Fi|Thriller
# 77     Action|Crime|Drama|Thriller
# 85          Action|Adventure|Drama
# 88                 Action|Thriller
# 93       Action|Adventure|Thriller
# 96                 Action|Thriller
# ...

# %%
movies[is_action].head()
# Out:
#     movieId                    title                              genres
# 5         6              Heat (1995)               Action|Crime|Thriller
# 8         9      Sudden Death (1995)                              Action
# 9        10         GoldenEye (1995)           Action|Adventure|Thriller
# 14       15  Cutthroat Island (1995)            Action|Adventure|Romance
# 19       20       Money Train (1995)  Action|Comedy|Crime|Drama|Thriller

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
ratings_count.plot()
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
average_ratings = ratings[['movieId','rating']].groupby('movieId').mean()
average_ratings
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592
# ...           ...
# 131254   4.000000
# 131256   4.000000
# 131258   2.500000
# 131260   3.000000
# 131262   4.000000
#
# [26744 rows x 1 columns]

# %%
movie_count = ratings[['movieId','rating']].groupby('movieId').count()
movie_count
# Out:
#          rating
# movieId
# 1         49695
# 2         22243
# 3         12735
# 4          2756
# 5         12161
# ...         ...
# 131254        1
# 131256        1
# 131258        1
# 131260        1
# 131262        1
#
# [26744 rows x 1 columns]

# %%
tags
# Out:
#          userId  movieId            tag
# 0            18        1    Mark Waters
# 1            65        1      dark hero
# 2            65        1      dark hero
# 3            65        1  noir thriller
# 4            65        1      dark hero
# ...         ...      ...            ...
# 465560   138446        1  Jason Bateman
# 465561   138446        1         quirky
# 465562   138446        1            sad
# 465563   138472        1  rise to power
# movieId       1        1              1
#
# [465549 rows x 3 columns]

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags,on='movieId', how='inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag
# 0    1644                                 Watched
# 1    1741                      computer animation
# 2    1741                 Disney animated feature
# 3    1741                         Pixar animation
# 4    1741  TÃ©a Leoni does not star in this movie

# %%
tags = pd.read_csv(r"C:\Users\User\Desktop\Data Science & AI\Projects\Pandas Project\tag.csv")
tags
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
del tags['timestamp']
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465564 rows x 3 columns]

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t
# Out:
#         movieId               title  \
# 0             1    Toy Story (1995)
# 1             1    Toy Story (1995)
# 2             1    Toy Story (1995)
# 3             1    Toy Story (1995)
# 4             1    Toy Story (1995)
# ...         ...                 ...
# 465543   131258  The Pirates (2014)
# 465544   131258  The Pirates (2014)
# 465545   131258  The Pirates (2014)
# 465546   131258  The Pirates (2014)
# 465547   131258  The Pirates (2014)
#
#                                              genres  userId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    1644
# 1       Adventure|Animation|Children|Comedy|Fantasy    1741
# 2       Adventure|Animation|Children|Comedy|Fantasy    1741
# 3       Adventure|Animation|Children|Comedy|Fantasy    1741
# 4       Adventure|Animation|Children|Comedy|Fantasy    1741
# ...                                             ...     ...
# 465543                                    Adventure   28906
# ...

# %%
avg_ratings= ratings.groupby('movieId',as_index=False).mean()
del avg_ratings['userId']
avg_ratings
# Out:
#        movieId    rating
# 0            1  3.921240
# 1            2  3.211977
# 2            3  3.151040
# 3            4  2.861393
# 4            5  3.064592
# ...        ...       ...
# 26739   131254  4.000000
# 26740   131256  4.000000
# 26741   131258  2.500000
# 26742   131260  3.000000
# 26743   131262  4.000000
#
# [26744 rows x 2 columns]

# %%
box_office = movies.merge(avg_ratings, on='movieId', how='inner' )
box_office.tail()
# Out:
#        movieId                          title                    genres  \
# 26739   131254   Kein Bund für's Leben (2007)                    Comedy
# 26740   131256  Feuer, Eis & Dosenbier (2002)                    Comedy
# 26741   131258             The Pirates (2014)                 Adventure
# 26742   131260            Rentun Ruusu (2001)        (no genres listed)
# 26743   131262               Innocence (2014)  Adventure|Fantasy|Horror
#
#        rating
# 26739     4.0
# 26740     4.0
# 26741     2.5
# 26742     3.0
# 26743     4.0

# %%
is_hughly_rated= box_office['rating']>=4
box_office[is_hughly_rated][-5:]
# Out:
#        movieId                                              title  \
# 26737   131250                              No More School (2000)
# 26738   131252  Forklift Driver Klaus: The First Day on the Jo...
# 26739   131254                       Kein Bund für's Leben (2007)
# 26740   131256                      Feuer, Eis & Dosenbier (2002)
# 26743   131262                                   Innocence (2014)
#
#                          genres  rating
# 26737                    Comedy     4.0
# 26738             Comedy|Horror     4.0
# 26739                    Comedy     4.0
# 26740                    Comedy     4.0
# 26743  Adventure|Fantasy|Horror     4.0

# %%
is_Adventure = box_office['genres'].str.contains('Adventure')
box_office[is_Adventure]
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 7            8                                Tom and Huck (1995)
# 9           10                                   GoldenEye (1995)
# 12          13                                       Balto (1995)
# ...        ...                                                ...
# 26683   131084                   Hui Buh: The Castle Ghost (2006)
# 26687   131092  Mickey, Donald, Goofy: The Three Musketeers (2...
# 26736   131248                              Brother Bear 2 (2006)
# 26741   131258                                 The Pirates (2014)
# 26743   131262                                   Innocence (2014)
#
#                                             genres    rating
# 0      Adventure|Animation|Children|Comedy|Fantasy  3.921240
# ...

# %%
box_office[is_Adventure & is_hughly_rated]
# Out:
#        movieId                                              title  \
# 257        260          Star Wars: Episode IV - A New Hope (1977)
# 593        599                             Wild Bunch, The (1969)
# 708        720  Wallace & Gromit: The Best of Aardman Animatio...
# 891        908                          North by Northwest (1959)
# 952        969                          African Queen, The (1951)
# ...        ...                                                ...
# 26611   130586                Itinerary of a Spoiled Child (1988)
# 26655   130996                         The Beautiful Story (1992)
# 26667   131050  Stargate SG-1 Children of the Gods - Final Cut...
# 26736   131248                              Brother Bear 2 (2006)
# 26743   131262                                   Innocence (2014)
#
#                                             genres    rating
# 257                        Action|Adventure|Sci-Fi  4.190672
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_genres = movies['genres'].str.split('|',expand=True)
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
movies_genres['isComedy']= movies['genres'].str.contains('Comedy')
movies_genres
# Out:
#                         0          1         2       3        4     5     6  \
# 0               Adventure  Animation  Children  Comedy  Fantasy  None  None
# 1               Adventure   Children   Fantasy    None     None  None  None
# 2                  Comedy    Romance      None    None     None  None  None
# 3                  Comedy      Drama   Romance    None     None  None  None
# 4                  Comedy       None      None    None     None  None  None
# ...                   ...        ...       ...     ...      ...   ...   ...
# 27273              Comedy       None      None    None     None  None  None
# 27274              Comedy       None      None    None     None  None  None
# 27275           Adventure       None      None    None     None  None  None
# 27276  (no genres listed)       None      None    None     None  None  None
# 27277           Adventure    Fantasy    Horror    None     None  None  None
#
#           7     8     9  isComedy
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies['year']=movies['title'].str.extract('.*\((.*)\).*', expand=True)
movies.tail()
# Out:
#        movieId                          title                    genres  year
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy  2007
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy  2002
# 27275   131258             The Pirates (2014)                 Adventure  2014
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)  2001
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror  2014

# %%
tags = pd.read_csv(r"C:\Users\User\Desktop\Data Science & AI\Projects\Pandas Project\tag.csv",sep=',')
tags
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp    object
# dtype: object

# %%
tags['parsed_time'] = pd.to_datetime(tags['timestamp'], unit='s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: '2009-04-24 18:19:40'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-155-d57aa4cf7d2f> in <module>
# ----> 1 tags['parsed_time'] = pd.to_datetime(tags['timestamp'], unit='s')
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     803             result = arg.map(cache_array)
#     804         else:
# --> 805             values = convert_listlike(arg._values, format)
#     806             result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
tags
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
grater_than_t = tags['timestamp']>'2015-02-01'
selected_rows = tags[grater_than_t]

# %%
selected_rows
# Out:
#         userId  movieId                 tag            timestamp
# 301        318      260               1970s  2015-02-20 22:42:49
# 302        318      260             fantasy  2015-02-20 22:42:49
# 303        318      260              sci-fi  2015-02-20 22:42:49
# 304        318   115149              Action  2015-02-21 15:58:30
# 305        318   115149             Revenge  2015-02-21 15:58:03
# ...        ...      ...                 ...                  ...
# 464962  138301   109487     science fiction  2015-02-05 23:17:35
# 464963  138301   109487      Self-Indulgent  2015-02-05 23:16:59
# 464964  138301   109487               space  2015-02-05 23:19:03
# 464965  138301   109487  visually appealing  2015-02-05 23:18:39
# 464966  138301   109487    wasted potential  2015-02-05 23:16:52
#
# [12130 rows x 4 columns]

# %%
tags.shape, selected_rows.shape
# Out:
# ((465564, 4), (12130, 4))

# %%
tags.sort_values(by='timestamp',ascending=True)[:100]
# Out:
#         userId  movieId                 tag            timestamp
# 333932  100371     2788        monty python  2005-12-24 13:00:10
# 333927  100371     1732       coen brothers  2005-12-24 13:00:36
# 333924  100371     1206     stanley kubrick  2005-12-24 13:00:48
# 333923  100371     1193      jack nicholson  2005-12-24 13:02:51
# 333939  100371     5004       peter sellers  2005-12-24 13:03:19
# ...        ...      ...                 ...                  ...
# 256660   75141     3183           ed harris  2006-01-10 12:09:22
# 333938  100371     4082            bukowsky  2006-01-10 17:06:06
# 333928  100371     1884               drugs  2006-01-10 17:08:41
# 333929  100371     1884  hunter s. thompson  2006-01-10 17:08:41
# 333925  100371     1208           crazy war  2006-01-10 17:09:10
#
# [100 rows x 4 columns]

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId', as_index=False).mean()
average_rating.tail()
# Out:
#        movieId  rating
# 26739   131254     4.0
# 26740   131256     4.0
# 26741   131258     2.5
# 26742   131260     3.0
# 26743   131262     4.0

# %%
joined = movies.merge(average_rating, on='movieId', how='inner')
joined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995  3.921240
# 1                   Adventure|Children|Fantasy  1995  3.211977
# 2                               Comedy|Romance  1995  3.151040
# 3                         Comedy|Drama|Romance  1995  2.861393
# 4                                       Comedy  1995  3.064592
